# %% [markdown]
# # Generador de texto con arquitectura One-to-Many
#
# ##Introducción.
# Un generador de texto es una API que utiliza un modelo de lenguaje no supervisado, capaz de generar parrafos de texto.
#
# A continuacion veremos un ejemplo de esto.

# %% [markdown]
# Importamoslibrerias

# %%
import os
import numpy as np
import re
import shutil
import tensorflow as tf

# %% [markdown]
# En la variable **CHECKPOINT_DIR** se guardaran los pesos del modelo cada 10 épocas

# %%
DATA_DIR = "./"
CHECKPOINT_DIR = os.path.join(DATA_DIR, "chekpoints")

# %% [markdown]
# Preparar los datos

# %%
def download_and_read(urls):
  texts = []
  for i, url in enumerate(urls):
    p = tf.keras.utils.get_file("ex1-{:d}.txt".format(i), url,cache_dir=".")
  text = open(p, "r").read()
  # borrar la marca de orden de bits
  text = text.replace("\ufeff", "")
  # cambiar lineas nuevas por espacios
  text = text.replace('\n', ' ')
  text = re.sub(r'\s+', " ", text)
  # añadir cada una a la lista
  texts.extend(text)
  return texts
  
texts = download_and_read([
"http://www.gutenberg.org/cache/epub/28885/pg28885.txt",
"https://www.gutenberg.org/files/12/12-0.txt"
])
# Out:
# Downloading data from http://www.gutenberg.org/cache/epub/28885/pg28885.txt
# 180224/177479 [==============================] - 0s 1us/step
# Downloading data from https://www.gutenberg.org/files/12/12-0.txt
# 196608/193648 [==============================] - 0s 1us/step

# %% [markdown]
# Crear el vocabulario

# %%
vocab = sorted(set(texts))
print('vocav size: {:d}'.format(len(vocab)))
# Out:
# vocav size: 86

# %% [markdown]
# Mapeo de palabras a enteros (int)

# %%
char2idx = {c:i for i,c in enumerate(vocab)}
idx2char = {i:c for c,i in char2idx.items()}

# %% [markdown]
# Numerizar el texto

# %%
texts_as_ints = np.array([char2idx[c] for c in texts])
data = tf.data.Dataset.from_tensor_slices(texts_as_ints)

# %%
seq_length = 100
sequences = data.batch(seq_length +1, drop_remainder=True)

# %%
def split_train_labels(sequence):
  input_seq = sequence[0:-1]
  output_seq = sequence[1:]
  return input_seq, output_seq

sequences = sequences.map(split_train_labels)
batch_size = 64
steps_per_epoch = len(texts) // seq_length // batch_size
dataset = sequences.shuffle(10000).batch(
batch_size, drop_remainder=True)

# %% [markdown]
# Definir el modelo

# %%
class CharGenModel(tf.keras.Model):

    def __init__(self, vocab_size, num_timesteps, 
            embedding_dim, **kwargs):
        super(CharGenModel, self).__init__(**kwargs)
        self.embedding_layer = tf.keras.layers.Embedding(
            vocab_size,
            embedding_dim
        )
        self.rnn_layer = tf.keras.layers.GRU(
            num_timesteps,
            recurrent_initializer="glorot_uniform",
            recurrent_activation="sigmoid",
            stateful=True,
            return_sequences=True
        )
        self.dense_layer = tf.keras.layers.Dense(vocab_size)

    def call(self, x):
        x = self.embedding_layer(x)
        x = self.rnn_layer(x)
        x = self.dense_layer(x)
        return x

# %% [markdown]
# Construir el modelo

# %%
vocab_size = len(vocab)
embedding_dim = 256
rnn_output_dim = 1024

model = CharGenModel(vocab_size, seq_length, embedding_dim)
model.build(input_shape=(batch_size, seq_length))
model.summary()
# Out:
# Model: "char_gen_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        multiple                  22016
# _________________________________________________________________
# gru (GRU)                    multiple                  107400
# _________________________________________________________________
# dense (Dense)                multiple                  8686
# =================================================================
# Total params: 138,102
# Trainable params: 138,102
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Definir la **loss function** y compilar el modelo

# %%
def loss(labels, predictions):
  return tf.losses.sparse_categorical_crossentropy(
      labels,
      predictions,
      from_logits=True
  )
model.compile(optimizer=tf.optimizers.Adam(), loss=loss)

# %% [markdown]
# Generar el texto

# %%
def generate_text(model, prefix_string, char2idx, idx2char,
        num_chars_to_generate=1000, temperature=1.0):
    input = [char2idx[s] for s in prefix_string]
    input = tf.expand_dims(input, 0)
    text_generated = []
    model.reset_states()
    for i in range(num_chars_to_generate):
        preds = model(input)
        preds = tf.squeeze(preds, 0) / temperature
        pred_id = tf.random.categorical(preds, num_samples=1)[-1, 0].numpy()
        text_generated.append(idx2char[pred_id])
        input = tf.expand_dims([pred_id], 0)

    return prefix_string + "".join(text_generated)

# %% [markdown]
# Correr y evaluar el modelo

# %% [markdown]
# Para no imprimir warnings y ver el texto mas limpio

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
num_epochs = 200
for i in range(num_epochs // 10):
    model.fit(
        dataset.repeat(),
        epochs=10,
        steps_per_epoch=steps_per_epoch,
        verbose = 0
    )
    checkpoint_file = os.path.join(
        CHECKPOINT_DIR, "model_epoch_{:d}".format(i+1))
    model.save_weights(checkpoint_file)
    gen_model = CharGenModel(vocab_size, seq_length, embedding_dim)
    gen_model.load_weights(checkpoint_file)
    gen_model.build(input_shape=(1, seq_length))
    
    #print("after epoch: {:d}".format(i+1)*10)
    print(generate_text(gen_model, "Alice ", char2idx, idx2char))
    print("---")
# Out:
# Alice both ut I on’t cou tiek the lof ict yout, “Itles was UBfexprsikk!” “Hullf diw and’t on dowser edf cof toulf wave thatked to ! the waid.”’s breer piy, Het ot she woming lith a dis an candey. “I wingad in I, as to u wangwain fnounzn. Thooullly. s%oje_vingre tisice as oflbete the utling laut: hing as as thabpe—ard, as bail, and a thid ieden wevert ive com—the herly andpled hico fere nom at sayze.” I wer, heady pur, I you ty eascas hen waste. Sums, bullve main’s_inghy hant the in the in atind at on tisery’t hinger.” whant..” O Gu,—himike avery becres, an liGly,” in HerPpat wiow. “Ald it Why horde!” jis Chan; a tweed mraigry tas fome and of she pus’s sonee bar ente hare nat.” xind, and hund in tig of reasme ing in ig I mamly aslcrecubpaid, am atter arase sullous noled Forny in If hare’th of griss wigg bpar licerk, cto kscot aving!” And ritked fne tewlyichee to of at Durtly Ducelte, _fow youch?” “"nmised QueterFer’t wanked platr a ith sorer a Quo vead! wheed. “lo the allishs, hod the_ sinbev
# ---
# Alice And you are some it ofly freds an of, all wase a thes, but don’t the Red Queen with ‘I’ve was laredsenberg-the maming in lanice cokn’t fut got and wos I poou likeod noensthat elasing, in and cones, andt the pliyivill, the Uning longer to the Alice in furtost had the Queer,” Alice the she got bremans one reftreight to be door, caming and skidn Suppather way verum orw thather? It’p noind at agropy, “oning it timing of undounhed not?” she for is taed Jher I wenm, butwing Dumpttiss foablect, bremave noway wor, thver Alice came soma over mass so thing mavelf you thing. * it Alice, so timptice—"like kepse sood onserured to cans fin, not ince.” “She Alice youre have and grouse forted testdle sloout in teing to got was brous, over ure as his for, for the hild. “They meeely, Alo it.” Alice—and you ligking the bronsty as there wook your! Ong hery, she you know the one Queeng. ““I very to meader nowing a marbe_s warkn’—mvenself light ofwing a peis begenuten here,” Alice be crormald inserong exmou
# ---
# Alice taors of crige to Queen, and sten me vontery denver enow!” she can get dist for at tell) neat this mane whit you mest um dowy craiblice, the kniw but to that sureht they, to reepwere, bust fealy: our sursel, and to dist tome, thook them!” “I tadd,” Alice saigh ine dong one had save in the uped to thint qurealled Alice,” the Knight them well exten, she was draing dook a other tnow pomaling to. So her plifpiaris. You make a Co—I don’t Humpty Tith was daiccelf, is.” “Throughing astrout deat, mode was shourdled the wory every Proum the Ploject Dous that shought? CHAPTESQE **H *f Of I whits what tim insting she on have swapmost out licover inst out again nof ‘browaich a book doned don’t rever a looking her own me dly, I save own. Roine it ite hear anget hery offersted opesh! There of thauss—berut it’ than should her Tweed 8ing the car that they and had felully unable it upny. “It’st, and said. “That eBlayaled mise do: as speadning of the emburst wer intorrouth-cam, ‘_I went some reakilyited
# ---
# Alice AMgane I surchisat so!” Alice one her a lous, ‘_mac_ you!” To fine—all they had veithing a gwand ow horseled at in have in the uses ench againg, “When noty dead the Queen, then and agand the wis! * * * * * That’s dist remark. There’s the lass vook Project Gueen it was it island the gow in liquted at soe: ands wert a to the Sort: and wond the sive to mpous?” ho pase as she slake only gat she?” The Knight and remarking withecsationateor?” she said. “However shore all was her diffo you cun the threep and spede up this oppose Oh the lergaty seeply, Is _ave_ ofteer for lesseld and so yours. “In a Mooks the caunts e-could each one remiss!” “O of its, as he wanded withen so the tood twough any Tike,” said the King, “love to be a fruttears of only knam meac!” of tee won’t do no, when, course’s faint, bull inttary—he postring and by,” Alice said, and gointed. “Dold midding byarkly an a relice,” the Sudeend: thet romium and begif, and argum. “Af she cogrishy the mang. “Oh, and siid, as Knight, t
# ---
# Alice got which sad nell more song to shourse at the no may!” “He said, ‘_looked the Project Gutting evous tone wasn’t “ball lest three we her helal!’” Alice expens whopet looked: “the Lipent you’ve bright kith be again?” said Alice, crost dimpty. “I mut the toong buld-act it sood thought distributing the etay scomanted a figh like they said, see. “I kild!” “Conryire, for at to your herse you know!” “It Alices. “Chinks_, ous a first out it up brewnose, sun work. The eferly—little, to to that (You midedud the Fundence?” Alice had had a peates, but I tend more had hadder told all cares than it somemether a Farge things", and to gare Some’s hill a carning a telf, as one with the bemark, you tuddenly at’s to smiled. Angown all the wippenack her hay toof! On further to Alice: “Oh, “nor, I was in a has (world tryes, and so me to sein, and than thingsty, and there a too; I main_ put (“I joining I fein to know?” Alice was I _that_ lake about this eartion afrein all or any invent on,” she spoks did g
# ---
# Alice That’s, who said. “I Queen in the _cellesed to spoken saw of the needs set out on time eyes, voor? She know!” “Yeard you find the Rey thing. The said ake on here I do frled very moment to when, of putting soly of the turnnint.’ Even there is was very bark it so the bother.” “That or happened out Alice. “It meantly, you know,” the Knith that it, “I mudded the sto—” anything of it for time, loons of his heamed at last, in you’ll statt!” “No say the Unicorn till in the proke: then the sount could _move_, and hove mush the look like here about it. “Meally began so much to that’s moment: I didf—Both, Is indly you’ve nLingly like herself, so!” There was the terd—” the sill see here up, as he coptain a brick! It’s trace to she "Projutty, for suck of ne being it!” “Howwo. They know—He; I _non’s it Alice could nother.” “But of the other bagesbire the Glaphed-have here. “Then he waiter, as she remain of though, I suded,” said the call to pelandudepan her strapting. “I pats!” ‘Alice streacpribute
# ---
# Alice asked, as whire the Walrus the browt drederunt interral went as law and to of the top girth, and with wayit said a restrone door house it his namuzze a little and open’t sheequiredumphadumm.: “I know!” said Alice. “It’s got her moncimains to gutr: with was loud the Unicorn hearl treanco the masting hand,” have not_—ourse there a broatered up alpected, in plaing to deng battle—just on or!” Alice caught in she sat silencold betoum, and a fish you collre trice, not to down treoff, cant at the with as she got just of cheeper, clearve had buttory iss, in she make to them whichtary;’” Alice said for they wondered ‘Baytly. “And see—but it round Alice again, and there with the let?” Alice have g that 200, book,” said the Queen said, my not traiming or all and got through the Foundayble sear one of more as invented and sating, the statty. “I’m like outhes adong nuck to dish thingers had in the fings 1.. 5nso. When a pauddess—just arage in it,” said “It suin down a little suray now I’ll thing ea
# ---
# Alice Fius?” she coky is curply.) ‘Yes, I tinll whith the voice and hishes yours poor and be gented voice sort mumber at last, so Alice couldn’t hardly after thr eyes, Kitty, what it, in it in a la. It’s very engwallen: ames,” he sort of precon!” There welr pallace, as he come by possions enough. * * * * * * * * * * * * * * * * * * * * * * There went off, all the light. Well whose blarge or dreams oun it always we went all.” Humpty Dumpty I muching the panes and tex— findly. Oh!” said Alice, be a game in a right somethingly go much meg, in a moment an inn?” “Alice Red Redng. Alice carnwing not _you_, I shard at the wabe, Alice he scranded as if you know one with a little _is fly in yever?” Huppandes. I must shouse it taking to the table?” Humpty’ (when they arge of large remark: Coppened tried tears very _back. Nowrien marked ceir dochitting my put it’s all on her,” the Rose’d quice off thun, any of hair ment to the complease what it was nothing in the vook es all tice of fortle into a large
# ---
# Alice new ‘it, and said “Ahy_ any moner? I come is oled with manag" never heaking in a Unicorn?” she would be first they, there was stirn’t de baflicmare!” she said the bamphaturts do!” Alve goigs they be hippose they Queen sugh to got the plashe. “But it had as she said) said with horse if you reat Alice, she poor and wwshe chinted with the duspencied puct,” the Knight call king flace, I hadn’t know, I’ve has, purest never parth it crown, then she rathifing this timbles with or too brooks as she broughis is pate a white she cried, just in a could hairrs!” “I tequice one she mub, “that?” said Alice, and the Eighth great on, yill not let it wass of thisly. “You somet’s to try out every round at from the to exactly looking a minute of Alice to herself, words to fase to beginning usloece—she was up a moment colle to ‘jopens. Seemand hand—and there Fiuntry. “You know _you_ think in all hand tow. AS I gave thing: when stic like it—and so voice interraiduning your pretty to gavemest of here—That’s
# ---
# Alice mumbling hill?” Alice man both proed. “Your darchick or stay shouting androor came whatever; 4-gleaboluters would had haund oldally hearry. PThaw, I sund they couldn’t reaved, as it’lut would never covers down as she shressed an are it,” the Qu _dea_, Dinarre?” “I supping donation?” “In in a messen: “but is the means what that prot henden gounted. “There’s sity neicun, I seeming a ‘pleased in the wentall for it an any wawk there” It’ll sile as walking at hands of you place And she went on with kniting like" the wood,” recover the timing great forsticular you hadd at the, it handself?” said the Queen samesy with round must state.” “It’s a name again?” she was very ovig with us, if you ellemed for to dr welt seemed very track it!” “I do use it wouldn’t “You mice glas palles a fast sick,” she had two much a laws entover said for a minute, “We have to shout, which and good-rility-cauted tone.” Alice went obpation up yetch and gently. “The dished trademed out. Four. I said why: I suppore ab
# ---
# Alice ‘Belit you, inventeve hastery, Evet to be great explancermaties to doirroblion as she could meftur almow-dimely help his here.” “I may asky away.” This mocour that it wasked “I can’t midd very had just the finvouse, parthit ladders sew her noticedly-distribution viry garted there first mt Ho much to link this wing and dear, now—“My _ought_ anxiously again, and strquare-that, you know.” The poor Alice was spread with waich the rinp of their finged a vice dest lake their hand, “Oh, that it would hould hard added at the shorks at it,” Alice sality CHAPTER IX. Queen said. “Contry,” he said. “I sund the wionshing mavity, at alonsw.” “It was large withen and been access works and smious.” See is!’ Tweedledee For here again, “all chip as _are_ it panted tadded to he suppored, and as see o with guesty you to the timal down got remark, and sticke that every namection you _toor Alice. “In and Alice cold,” he said to exill as Havawn,” said the nice. “It were supporty moment, they it no, hopfevent
# ---
# Alice her head, in ond take they to chiles aftery found prose with of them that his queat would be soon expented to is to the coment, and she round the poor and shapuce of make going to be.ng it faunds like it!” cried the King. Alice ream!” Alice abally were this looking per-post: and do here,” the Red Queen only to herself, for fell just large vast! Well, Reall,” said the King. “Then you’ve next dream, but while said, “I do you think it’s allittarA As Alice EawBoy to the time, and it turn’t held heawware try,” the Carpertuphaning to hers. “Noto my we didn’t donoutinily_ dowing the distributions be me earthing-pantions the blatted quicket.” “I wishovid saw it many talk.” Her dose?” Alice crow in a roop of confing!” Surpedly—on and display!” “if that is Alice very on tiked down od, only the bort Didia notiaculding, in her usher with a thing, distribl; “It wouldn’t—” “He went in hard that done was that I’ll Project Gutenberg), ampsesation strol. So the wichecked on standly—wither polits down a
# ---
# Alice thing Licentenberg-tm clve brandief, that was in never sand of tur-nut—But I ever sent to tried. She had go moment in a slowly return’t hear you waken surathing a diffendeds. ‘_sops__’ if with my wlitely, “whisperst of an ely laughe. Bes _some the way,” said the Red Queen, bbout.” “Himself Us changoss with the horse-dioncildren the great hid excess tealt to can’s flac!” Alice said, nonly as you very, that’s vain Ammating any discunibuters sometite a black about the great dartle as last his collection with into a faull bad you see voice asking some asleep. Then my is quite as with a drecr—in side or been the wood-happen quidee to see here asking, she was reached bother mome of mark. “If she went on, “of chill an ember my nearmbace us!’ The Jabbarms of hon yet, and it fild us parly of your manding doyall you must down which will was a word. Contrabjum-came poet. “You mady isperumphis off out of the tong. “Oh!” she talk: what in she thought the you off ture it? And there it’s breadly abou
# ---
# Alice like a the same donations square! And your face in a little very exaice oh it, that they parth, cake memnationsating outle. She had some mays of ran sitting and snick, you’ll tell you did not mean.” “No, if you get up the kitten was law a light, they converline full of very nearly.” “Now, with the rwose dions looked nof you to evenyill is while this, just trees, and the mounterbode die work house they heading, where look on shake her license, and Alice purr, and when they moup you smallay, and then stood-nup as I were as she was then this while Sheep let, when I can his no shall remactel: wat it beginning!” (“I should_ wait?” let make phrass, without sed lowers to the erg-trabe the perilding you,” said Tweedledum. Which I can’t must be soing her grunt; All Walrus,” the nest they can be foubt, as to corle its breaddle!” Here so Hatterily _them_ dar—the King took. "Nugg marked they clase?” she conving laught the whice any so, that they cump a jouct them try, Of child,” she said in all. B
# ---
# Alice watchice eating for pareatible lily, and then she was returen, I should think on the scrange of the way I’ve slecin that she said my the pourse, so there it’s gave all. And an gensenter got to through the darge you full just side in a night on the niggly like as diffinienters to head, buthing on, iten for a little great a next now,” said the Red Queen buttle pressed was that suppos to cur round nothen Humpty Dumpty said as seat entice would remark, and went Alice, bell me only as the next every off, we’w for do him out to shall thisglement a hunging nonsense, and thinking it several to afraid it,” said Alice, as it is wait it about fang!” “There it well in a mining him, I didn’t cam, giffers all on this keep from,” said the Tiger-lily (and asn regemany alruse of mums now!” she seive be internair ‘TWecer mean was a queer wanter back. “You __kitting Tweedledum_ cried. “Youe _shed I don’t Gutenberg Licell because the soon more in a creation and labs. Uhow, you know.” Alice could way that
# ---
# Alice remarked with a long two good on would sall a Sniegly,” said the Red Queen. Kittyit—looked soon or ablinail cloud at laozzze them up none clos back!” Alice covers at her eyes, cemettate!” thiwed the worlder your eBooks Project Gutenberg-tm heartwarding—‘The chappone,” to have not a feeve of the frose, you know _ought_ it weare his arms fuch anxious whet say ‘Is shake it was!” the White King sorman, “a __that_ conjoying for Haxt to hear, was worked with then bee _you_ a soldiech eatureld at the pat-mack to the welese on was flime?” he said. “There’s do usely pause of islement, thinked clorge did in such alum. “However—how it wouldn’t didn’t manage! What don’t secticks one.” “Then “I’ll on, this mought among again, and he said, “om a porses that I say I can’t seea made it,” the Lion’s favontiless exatitoldey way, it’s ‘Mem!” “Why,” Tweedledee round al!” Alice quite do.” “Cewnow-tmis? Are. ‘You wince your other wouldn’t about all,” said Twicher.” This Complore, that leep has to go in a mi
# ---
# Alice minuted? It’s, of course yetate dane withouting to do alwave no, and diyald?” Humpty Dumpty beginning his flocto in the flower?” Alice said “One fees as with defecelf alreyse.” “It’s shest—and a little difficul out. Alice Tweedledum. (“The—” “He said not away.” “I compliunve her excin!” she seemed first,” said Alice with the hords ‘Here _your_: and I can’t Majesty him:— “If I mean; buten to, as if he did his reath at one asked! And you like any sourses, and sat that—” “Yes is was beginer managhal perfine: and arge an Alice could a regaruse so from reply-for?” Alice cried, we substr—such along the lagreented and armso, boto the back went eyes, said Humpty Dumpty. “There was so things forquant him a sent at your in _you_, but _vere_ shorted, puine looking on the rany?” Alice said, as it brothersfop the lapty taken’t cold, for the law sure the tumment furst in his goes afterlilar for it, and then. “Newfirelf very seemed to no, now—” The Knight said, “Whathingly so said Knight. Waittle see
# ---
# Alice hear-lick!” “Ho his proed, by Liveftered. “OR Gof ans pressed, this worlfth was, for it bring it yetchedn’t quite conagers to make the wind!” she spoke itself, pury imperstance somests and said tweder_s yet: it said is so easy,” Alice said, and said because from the screstrabill the middle are two or! But Alice said at the taoks for it went the blying her ore there, and she patr its—there she thought.’ ‘You leave any wwords holded it as _I_ yeard,” as if hunk with a call syee fough _I’ve_ bead out pretended “You’re make an Justs away,” said the King. “Why, she only is a lorpsicuidum. “We’s she cakes. 1.E.1,,” All cat of the Project Gutenberg-tm electronic wichous very indily. “And anything of that do-hary _cap_ it has somethaninut, and before in was “you may afterwards quite flowers to head.” “That’s, that hold of voices went on to say hurhancaling (he’s standing of cate. Then af as you knived on the Carres but wondered this managedly. “Do you know,” the Knight said, as she spoken from
# ---
# Alice herses pencilemed to Project Gutenberg Lile But that round interuntipy donation voices of the forman. “Yes, now what can’t help sibe of rrogbed there weptevar each fast me,” Alice like a fretend his own reass, that are voy the windowwhem from while the fame of it!” “Now!” “Now I was think?” “No, you don’t as a battin! What down the toopt will with the permen them. That’s life—only _mome_ back dother more are a? Cought the inself!” “Fittites and sticking so. She spoke is check to the rusmer him asimes an into any capesity. “Me _cream_ capess! Did_ said, not understation, though Alice tere the tinner of the full tamousely: “better!” she went out; but—verse, seizing sthe way that fegior releath. O hear I don’t know “I haven’t fron they will proughadew it meansed with great day. “It’s came in a minute?” said Alice, not care inquired. “And what’s the a little brother, “the thundering they way more that quarply eassion as he said off from Alice felling her you? It’s guen not yours, the Looki
# ---
# Alice could great felt dark to sell asking; but it movidesely were got up, from what hand her things of which it and last—something bown, and speak only much nerver air, it repeated on without some At af the meat cort!” said the misting his hands. But!” she thought. CHAPTER IX. CQuettemeen Interrally. “I dened Alice have the flatuce these it was instactly unking road?” the Walrus conder-flined as much at the Looking-Glass thriject Gutenberg-tm emmed him arm. “However, in here to beling holders sain for the Red Knight but it was the better. “I wonder wax _I’m_ inorag here frothing. They dake has, you know—round in perfor of mice drewing it, ‘The last in puring, you help to guess to saying, and get her,’ Tweedledee—ruttly, and mjae, while you’re just own gase for afraid and about begingers in the confised to do Alice memesten. “So foregs there, we comes to it wouldn’t keep which to chook sitnous,” said Alice: “I’m aframes and alwending by fiffing to go in a tmild hir too to ask?” “Whut bust ‘g
# ---
